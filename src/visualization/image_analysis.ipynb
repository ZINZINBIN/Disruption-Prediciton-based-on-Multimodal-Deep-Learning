# %%
import numpy as np

from src.dataloader import VideoDataset
from torch.utils.data import DataLoader

batch_size = 4
clip_len = 10
train_data_dist10 = VideoDataset(dataset = "fast_model_dataset", split = "train", clip_len = clip_len, preprocess = False,  augmentation = False)
train_loader_dist10 = DataLoader(train_data_dist10, batch_size = batch_size, shuffle = True, num_workers = 4)

test_data_dist10 = VideoDataset(dataset = "fast_model_dataset", split = "test", clip_len = clip_len, preprocess = False, augmentation = False)
test_loader_dist10 = DataLoader(test_data_dist10, batch_size = batch_size, shuffle = True, num_workers = 4)

sample_data, sample_label = next(iter(train_loader_dist10))
sample_img = sample_data[0, :, 0, :, :]

print("sample_img : ", sample_img.size())

from src.utility import show_frame

show_frame(sample_img)

for idx in range(0,clip_len, 2):
    sample_img = sample_data[0, :, idx, :, :]
    show_frame(sample_img)
# Out:
# Number of train videos: 1240
# Number of test videos: 388
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sample_img :  torch.Size([3, 112, 112])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sample_data, sample_label = next(iter(test_loader_dist10))
sample_img = sample_data[0, :, 0, :, :]

print("sample_img : ", sample_img.size())

show_frame(sample_img)

for idx in range(0,clip_len, 2):
    sample_img = sample_data[0, :, idx, :, :]
    show_frame(sample_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# sample_img :  torch.Size([3, 112, 112])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
